# %% [markdown]
# <a href="https://colab.research.google.com/github/peteciank/abc_datascience_classification/blob/main/%5B2%5D%20k_nearest_neighbors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # K-Nearest Neighbors (K-NN)

# %%
# K-Nearest Neighbors (K-NN)

## Importing the libraries

import numpy as np  # For array operations and mathematical functions
import matplotlib.pyplot as plt  # For data visualization
import pandas as pd  # For handling datasets

## Importing the dataset

dataset = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vQ-GzTqfan25hVJ4BrsZr0dimNorFVk7OQ49yGl39SWEEtL8pZ6qlSzZczV2jhg32Zni8AiPw0B3e-W/pub?gid=1606731410&single=true&output=csv')
# Replace 'ENTER_THE_NAME_OF_YOUR_DATASET_HERE.csv' with your actual dataset name
X = dataset.iloc[:, :-1].values  # Extract feature variables
y = dataset.iloc[:, -1].values  # Extract the target variable

## Splitting the dataset into the Training set and Test set

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
# Splits into 75% training and 25% testing data; random_state ensures consistent splitting

## Feature Scaling

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)  # Standardize features in the training set
X_test = sc.transform(X_test)  # Apply the same standardization to the test set

## Training the K-NN model on the Training set

from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors=20, metric='minkowski', p=2)
# Create a K-NN model with 5 neighbors, using Euclidean distance (p=2)
classifier.fit(X_train, y_train)  # Train the model on the training data

## Making the Confusion Matrix

from sklearn.metrics import confusion_matrix, accuracy_score
y_pred = classifier.predict(X_test)  # Generate predictions on the test set
cm = confusion_matrix(y_test, y_pred)  # Create the confusion matrix
print(cm)
accuracy_score(y_test, y_pred)  # Calculate the model's accuracy
# Out:
# [[103   4]
#  [  8  56]]
# 0.9298245614035088

# %% [markdown]
# ## Now, follow this step by step and see how it behaves
#
# **Key Points**:
#
# * **Dataset**: Make sure the dataset URL is correct and accessible.
# Features and Target: Check that you're extracting the correct columns as your features (X) and target variable (y).
#
# * **K-value**: The n_neighbors parameter is crucial. Try different values to see how it impacts your model's performance.
#
# * **Distance Metric**: 'minkowski' is a general metric, where p=2 represents Euclidean distance and p=1 represents Manhattan distance.

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vQ-GzTqfan25hVJ4BrsZr0dimNorFVk7OQ49yGl39SWEEtL8pZ6qlSzZczV2jhg32Zni8AiPw0B3e-W/pub?gid=1606731410&single=true&output=csv')
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %% [markdown]
# ## Splitting the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %% [markdown]
# ## Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# ## Training the K-NN model on the Training set

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
classifier.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# ## Making the Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
y_pred = classifier.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[103   4]
#  [  5  59]]
# 0.9473684210526315
